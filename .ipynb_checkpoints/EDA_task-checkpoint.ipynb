# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AddedFeatures_campaign_sale - AddedFeatures_campaign_sale.csv', index_col='Index')

# %%
df.head()
# Out:
#        Campaign Period Sales  Buy  Historical Sales Volume  \
# Index
# 0                 238.704762    1              146803.4286
# 1                 281.680000    1              439984.1600
# 2                 432.857143    1              970465.7143
# 3                   0.000000    0              230193.6000
# 4                 308.419048    1              182584.0762
#
#        Number of Prior Year Transactions  Number of Transactions  \
# Index
# 0                                     15                      15
# 1                                     22                      22
# 2                                     19                      19
# 3                                     17                      17
# 4                                     16                      16
#
#        Purchase Breadth  Customer_engagement_days  \
# Index
# 0                     2                     19170
# 1                     1                     14530
# ...

# %%
df.tail()
# Out:
#        Campaign Period Sales  Buy  Historical Sales Volume  \
# Index
# 12127                    0.0    0               32328.4000
# 12128                    0.0    0              920240.5333
# 12129                    0.0    0               71762.8800
# 12130                    0.0    0              265963.0629
# 12131                    0.0    0              702149.0667
#
#        Number of Prior Year Transactions  Number of Transactions  \
# Index
# 12127                                  6                       6
# 12128                                 26                      26
# 12129                                 21                      21
# 12130                                 18                      18
# 12131                                 20                      20
#
#        Purchase Breadth  Customer_engagement_days  \
# Index
# 12127                 1                      8778
# 12128                 0                      8717
# ...

# %%
df.shape
# Out:
# (12132, 25)

# %%
df.describe()
# Out:
#        Campaign Period Sales           Buy  Historical Sales Volume  \
# count           12132.000000  12132.000000             1.213200e+04
# mean              107.933384      0.270936             5.600768e+05
# std               267.200455      0.444462             7.039575e+05
# min                 0.000000      0.000000             0.000000e+00
# 25%                 0.000000      0.000000             1.792572e+05
# 50%                 0.000000      0.000000             3.678030e+05
# 75%               137.278000      1.000000             6.921952e+05
# max              5927.306667      1.000000             1.648348e+07
#
#        Number of Prior Year Transactions  Number of Transactions  \
# count                       12132.000000            12132.000000
# mean                           16.512117               16.500412
# std                             6.034094                6.040510
# min                             1.000000                1.000000
# ...

# %%
df.columns.tolist()
# Out:
# ['Campaign Period Sales',
#  'Buy',
#  'Historical Sales Volume',
#  'Number of Prior Year Transactions',
#  'Number of Transactions',
#  'Purchase Breadth',
#  'Customer_engagement_days',
#  'Days_since_last_transaction',
#  'Customer_engagement_length',
#  'Language_group',
#  'Repurchase Method',
#  'Last Transaction Channel',
#  'Number of Employees',
#  'Service Level',
#  'Do No Disturb',
#  'Email Available',
#  'Desk',
#  'Executive Chair',
#  'Standard Chair',
#  'Monitor',
#  'Printer',
#  'Computer',
#  'Insurance',
#  'Toner',
#  'Office Supplies']

# %%
df.nunique()
# Out:
# Campaign Period Sales                 3243
# Buy                                      2
# Historical Sales Volume              12103
# Number of Prior Year Transactions       59
# Number of Transactions                  59
# Purchase Breadth                        10
# Customer_engagement_days              2876
# Days_since_last_transaction           3031
# Customer_engagement_length               3
# Language_group                           4
# Repurchase Method                        2
# Last Transaction Channel                 8
# Number of Employees                      6
# Service Level                            2
# Do No Disturb                            2
# Email Available                          2
# Desk                                     2
# Executive Chair                          2
# Standard Chair                           2
# Monitor                                  2
# Printer                                  2
# Computer                                 2
# ...

# %% [markdown]
# Observation: There is no missing data

# %%
df.isnull().sum()
# Out:
# Campaign Period Sales                0
# Buy                                  0
# Historical Sales Volume              0
# Number of Prior Year Transactions    0
# Number of Transactions               0
# Purchase Breadth                     0
# Customer_engagement_days             0
# Days_since_last_transaction          0
# Customer_engagement_length           0
# Language_group                       0
# Repurchase Method                    0
# Last Transaction Channel             0
# Number of Employees                  0
# Service Level                        0
# Do No Disturb                        0
# Email Available                      0
# Desk                                 0
# Executive Chair                      0
# Standard Chair                       0
# Monitor                              0
# Printer                              0
# Computer                             0
# Insurance                            0
# Toner                                0
# ...

# %%
df.isna()
# Out:
#        Campaign Period Sales    Buy  Historical Sales Volume  \
# Index
# 0                      False  False                    False
# 1                      False  False                    False
# 2                      False  False                    False
# 3                      False  False                    False
# 4                      False  False                    False
# ...                      ...    ...                      ...
# 12127                  False  False                    False
# 12128                  False  False                    False
# 12129                  False  False                    False
# 12130                  False  False                    False
# 12131                  False  False                    False
#
#        Number of Prior Year Transactions  Number of Transactions  \
# Index
# 0                                  False                   False
# 1                                  False                   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12132 entries, 0 to 12131
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Campaign Period Sales              12132 non-null  float64
#  1   Buy                                12132 non-null  int64
#  2   Historical Sales Volume            12132 non-null  float64
#  3   Number of Prior Year Transactions  12132 non-null  int64
#  4   Number of Transactions             12132 non-null  int64
#  5   Purchase Breadth                   12132 non-null  int64
#  6   Customer_engagement_days           12132 non-null  int64
#  7   Days_since_last_transaction        12132 non-null  int64
#  8   Customer_engagement_length         12132 non-null  object
#  9   Language_group                     12132 non-null  object
#  10  Repurchase Method                  12132 non-null  object
# ...

# %%
df['Language_group']
# Out:
# Index
# 0        English
# 1        English
# 2        English
# 3        English
# 4        English
#           ...
# 12127    English
# 12128    Unknown
# 12129    English
# 12130    English
# 12131    English
# Name: Language_group, Length: 12132, dtype: object

# %%
bought_customers = df[df['Buy']==1]
bought_customers
# Out:
#        Campaign Period Sales  Buy  Historical Sales Volume  \
# Index
# 0                 238.704762    1              146803.4286
# 1                 281.680000    1              439984.1600
# 2                 432.857143    1              970465.7143
# 4                 308.419048    1              182584.0762
# 7                 223.440000    1              277512.4800
# ...                      ...  ...                      ...
# 12077             510.219048    1              510219.0476
# 12079             206.626667    1              132241.0667
# 12080             476.313600    1              876417.0240
# 12083             452.356667    1              312126.1000
# 12101             376.257143    1              240804.5714
#
#        Number of Prior Year Transactions  Number of Transactions  \
# Index
# 0                                     15                      15
# 1                                     22                      22
# ...

# %%
bought_customers_selected_columns = bought_customers[['Campaign Period Sales','Historical Sales Volume','Number of Prior Year Transactions']]
bought_customers_selected_columns
# Out:
#        Campaign Period Sales  Historical Sales Volume  \
# Index
# 0                 238.704762              146803.4286
# 1                 281.680000              439984.1600
# 2                 432.857143              970465.7143
# 4                 308.419048              182584.0762
# 7                 223.440000              277512.4800
# ...                      ...                      ...
# 12077             510.219048              510219.0476
# 12079             206.626667              132241.0667
# 12080             476.313600              876417.0240
# 12083             452.356667              312126.1000
# 12101             376.257143              240804.5714
#
#        Number of Prior Year Transactions
# Index
# 0                                     15
# 1                                     22
# 2                                     19
# 4                                     16
# 7                                     18
# ...                                  ...
# ...

# %%
df.Customer_engagement_length.value_counts().plot.pie()
plt.show()

# %%
sns.pairplot(data = df, vars=['Historical Sales Volume','Number of Prior Year Transactions','Customer_engagement_length'])
plt.show()
